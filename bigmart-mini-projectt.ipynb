# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %%
df=pd.read_csv("../input/bigmart-dataset/Train.csv")

# %%
# printing first five rows 
df.head()

# %%
df.shape

# %%
df.info()

# %%
#checking for nulls 
df.isnull().sum()

# %%
#filling missing values of Item_weight by mean value of its column
df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
# getting Mode "what occurs most number of times" for outlet size
df['Outlet_Size'].mode()

# %%
# fillinf missing values in outlet_size by Mode
df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0],inplace=True)

# %%
df['Outlet_Size'].value_counts()

# %%
#cheking
df['Outlet_Size'].isnull().sum()

# %%
# no nulls in datasets
df.isnull().sum()

# %%
#preprocessing
df.replace({'Item_Fat_Content':{'low fat': 'Low Fat','LF': 'Low Fat','reg':'Regular'}},inplace=True)

# %%
sns.countplot(df['Item_Fat_Content'])

# %%
sns.countplot(df['Outlet_Establishment_Year'])

# %%
lst=list(df['Item_Type'].unique())
chart=sns.countplot(df['Item_Type'])
chart.set_xticklabels(labels=lst,rotation=90)

# %%
sns.countplot(df['Outlet_Size'])

# %%
sns.distplot(df['Item_Outlet_Sales'])

# %%
sns.countplot(df['Outlet_Location_Type'])

# %%
lst=list(df['Outlet_Type'].unique())
chart=sns.countplot(df['Outlet_Type'])
chart.set_xticklabels(labels=lst,rotation=90)

# %%
#correlation
sns.heatmap(df.corr(),annot=True)

# %%
#label encoder 
encoder=LabelEncoder()

df['Item_Identifier'] = encoder.fit_transform(df['Item_Identifier'])

df['Item_Fat_Content'] = encoder.fit_transform(df['Item_Fat_Content'])

df['Item_Type'] = encoder.fit_transform(df['Item_Type'])

df['Outlet_Identifier'] = encoder.fit_transform(df['Outlet_Identifier'])

df['Outlet_Size'] = encoder.fit_transform(df['Outlet_Size'])

df['Outlet_Location_Type'] = encoder.fit_transform(df['Outlet_Location_Type'])

df['Outlet_Type'] = encoder.fit_transform(df['Outlet_Type'])

# %%
df.head()

# %%
#splitting
X=df.iloc[:,:10]
y=df.iloc[:,11]

# %%
# Splitting dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 41)

# %%
# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)

# %%
# Predicting the Test set results
y_pred=regressor.predict(X_test)

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_pred,y_test,squared=False))

# %%
#Fitting random forest to the Training set
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=1000)
rf_model=rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)

from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

mean_squared_error(y_test,y_pred)

# %%
r2_score(y_test,y_pred)

# %%
mean_absolute_error(y_test,y_pred)

# %%
#Fitting XGBoost to the Training set
model = XGBRegressor(n_estimators=10)

# %%
model.fit(X_train,y_train)

# %%
result=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,result)
